# %% [markdown]
# # matrix_mult
#
# > Multiplication between matrices.
# > __Objetive:__ transform the kernel so that each thread takes care of each element in the matrix C (result matrix).
#
# ## Usage
#
# ### Generate executable
#
# ```bash
# make
# ```
#
# ### Execute
#
# ```bash
# ./matrix_mult [hA wA/hB wB]
# ```
#
# For example:
# ```bash
# ./matrix_mult 16 16 16
# ```
#
# ## Output
#
# Time A (malloc and memcpy): X s
# Time B (malloc and memcpy): X s
# Time Kernel: X s
# Time C (cudaMemcpyDeviceToHost): X s
# Band width of A: X KB/s
# Band width of B: X KB/s
# Performance Kernel: X GFLOPS/s
# Band width of C: X KB/s
#
# > [!NOTE]
# > FLOPS = 2 * m * n * k;
#
# ## Expectations
#
# Band widths of A and B are faster than C's.
#
# ## Exporting results
#
# Export a `.csv` with different matrices sizes and a `.png` showing the comparations between those matrices.
#
# ```bash
# python3 exportResults.py
# ```

# %%
import pandas as pd
from IPython.display import Image, display

# Load the CSV file into a DataFrame
filenameCSV = 'matrix_mult_results.csv'
df = pd.read_csv(filenameCSV)

# Display the DataFrame
print("Data from CSV:")
display(df)

# Display the image generated by matplotlib
filenamePNG = 'matrix_mult_results.png'
print("Generated Plot:")
display(Image(filename=filenamePNG))
# Out:
# Data from CSV:
#    hA  wA/hB  wB  Time A (malloc and memcpy)  Time B (malloc and memcpy)  \
# 0   1      1   1                    0.586024                    1.117028
# 1   3      1   3                    1.675608                    0.146658
# 2  16     16  16                    0.698555                    1.153264
# 3  16     17  16                    1.674294                    0.099400
# 4  32     32  32                    0.653300                    1.115187
#
#    Time Kernel  Time C (cudaMemcpyDeviceToHost)  Band width of A  \
# 0     1.117342                         1.117686         0.006826
# 1     0.147047                         0.147480         0.007162
# 2     1.153946                         1.154647         1.465883
# 3     0.099865                         0.100348         0.649826
# 4     1.115545                         1.115874         6.269708
#
#    Band width of B  Performance Kernel  Band width of C
# 0         0.003581            0.000000         0.003579
# 1         0.081823            0.000000         0.244101
# 2         0.887915            0.000007         0.886851
# 3        10.945682            0.000087        10.204487
# 4         3.672927            0.000059         3.670665
# Generated Plot:
